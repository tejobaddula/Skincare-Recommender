# %% [markdown]
# ### Loading Libraries

# %%
import pandas as pd
import numpy as np
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Input

# %%
data = pd.read_csv("reviews.csv")
data.head()
# Out:
#        Reviewer Recommend  Stars         Date         Product     Category  \
# 0        Ayuika        No      3   5 days ago  Perfect 3D Gel  Night Cream
# 1  yustinalupit       Yes      4  16 Feb 2020  Perfect 3D Gel  Night Cream
# 2     evikdanny        No      3  13 Feb 2020  Perfect 3D Gel  Night Cream
# 3  daniskhoirun       Yes      3  08 Feb 2020  Perfect 3D Gel  Night Cream
# 4     hulahup19       Yes      5  08 Feb 2020  Perfect 3D Gel  Night Cream
#
#                   Date Scrape  \
# 0  2020-02-24 13:35:12.875052
# 1  2020-02-24 13:35:12.876053
# 2  2020-02-24 13:35:12.878054
# 3  2020-02-24 13:35:12.880038
# 4  2020-02-24 13:35:12.882056
#
#                                                  Url
# 0  https://reviews.femaledaily.com/products/moist...
# 1  https://reviews.femaledaily.com/products/moist...
# 2  https://reviews.femaledaily.com/products/moist...
# 3  https://reviews.femaledaily.com/products/moist...
# 4  https://reviews.femaledaily.com/products/moist...

# %% [markdown]
# ### Checking for missing values

# %%
data.isna().sum()
# Out:
# Reviewer       0
# Recommend      0
# Stars          0
# Date           0
# Product        0
# Category       0
# Date Scrape    0
# Url            0
# dtype: int64

# %% [markdown]
# ### Checking for duplicated values

# %%
data.duplicated().sum()
# Out:
# 0

# %%
id_count = pd.crosstab(index=data.Reviewer,columns='count').sort_values(by='count',ascending=True)
id_count
# Out:
# col_0        count
# Reviewer
# Tipee            2
# celindriana      2
# muna19           2
# murinaarg        2
# murti123         2
# ...            ...
# fitput         102
# SathyaTika     103
# mailaul        107
# rency          113
# takacchi       132
#
# [22360 rows x 1 columns]

# %%
name_r = id_count[id_count['count']>1]
name_u = name_r.index.to_list()
data = data[data.Reviewer.isin(name_u)]

# %% [markdown]
# ### dropping unused columns

# %%
data.drop(['Recommend','Date','Date Scrape','Url','Category'], axis=1, inplace=True)
data.rename(columns={'Reviewer':'reviewer','Product':'product','Stars':'rating'}, inplace=True)
data = (data[~(data['reviewer'] == ' ')])
data.head()
# Out:
#        reviewer  rating         product
# 0        Ayuika       3  Perfect 3D Gel
# 1  yustinalupit       4  Perfect 3D Gel
# 2     evikdanny       3  Perfect 3D Gel
# 3  daniskhoirun       3  Perfect 3D Gel
# 4     hulahup19       5  Perfect 3D Gel

# %% [markdown]
# ### Creating matrix pivot

# %%
matrix_pivot = pd.pivot_table(data,values='rating',index='reviewer',columns='product').fillna(0)
matrix_pivot.head()
# Out:
# product       0,2 mm Therapy Air Mask Sheet  \
# reviewer
# 01lely                                  0.0
# 01putrisalma                            0.0
# 01sary                                  0.0
# 123hayoapa                              0.0
# 15ayusafitri                            0.0
#
# product       10% Lactic Acid (Infused with Rose)  \
# reviewer
# 01lely                                        0.0
# 01putrisalma                                  0.0
# 01sary                                        0.0
# 123hayoapa                                    0.0
# 15ayusafitri                                  0.0
#
# product       100% Cold-Pressed Virgin Marula Oil  \
# reviewer
# 01lely                                        0.0
# 01putrisalma                                  0.0
# 01sary                                        0.0
# 123hayoapa                                    0.0
# 15ayusafitri                                  0.0
#
# product       100% Organic Cold-Pressed Borage Seed Oil  \
# reviewer
# 01lely                                              0.0
# 01putrisalma                                        0.0
# 01sary                                              0.0
# 123hayoapa                                          0.0
# 15ayusafitri                                        0.0
#
# product       100% Organic Cold-Pressed Rose Hip Seed Oil  \
# reviewer
# 01lely                                                0.0
# 01putrisalma                                          0.0
# 01sary                                                0.0
# 123hayoapa                                            0.0
# 15ayusafitri                                          0.0
#
# product       100% Plant-Derived Squalane  100% Pure Camellia Dry Oil  \
# reviewer
# 01lely                                0.0                         0.0
# 01putrisalma                          0.0                         0.0
# 01sary                                0.0                         0.0
# 123hayoapa                            0.0                         0.0
# 15ayusafitri                          0.0                         0.0
#
# product       100% Snail mucus Soothing Gel  14% AHA Swipes  \
# reviewer
# 01lely                                  0.0             0.0
# 01putrisalma                            0.0             0.0
# 01sary                                  0.0             0.0
# 123hayoapa                              0.0             0.0
# 15ayusafitri                            0.0             0.0
#
# product       2 Minutes Brightening Gel  ...  \
# reviewer                                 ...
# 01lely                              0.0  ...
# 01putrisalma                        0.0  ...
# 01sary                              0.0  ...
# 123hayoapa                          0.0  ...
# 15ayusafitri                        0.0  ...
#
# product       wardah seaweed intensive night cream  wardah suncare  \
# reviewer
# 01lely                                         0.0             0.0
# 01putrisalma                                   0.0             0.0
# 01sary                                         0.0             0.0
# 123hayoapa                                     0.0             0.0
# 15ayusafitri                                   0.0             0.0
#
# product       watermelon glow  \
# reviewer
# 01lely                    0.0
# 01putrisalma              0.0
# 01sary                    0.0
# 123hayoapa                0.0
# 15ayusafitri              0.0
#
# product       white beauty aqua facial wash with plant extract  \
# reviewer
# 01lely                                                     0.0
# 01putrisalma                                               0.0
# 01sary                                                     0.0
# 123hayoapa                                                 0.0
# 15ayusafitri                                               0.0
#
# product       whitening plus complex  whitening soap  wonder pore  zaitun oil  \
# reviewer
# 01lely                           0.0             0.0          0.0         0.0
# 01putrisalma                     0.0             0.0          0.0         0.0
# 01sary                           0.0             0.0          0.0         0.0
# 123hayoapa                       0.0             0.0          0.0         0.0
# 15ayusafitri                     0.0             1.0          0.0         0.0
#
# product       “Buffet”  “B” oil
# reviewer
# 01lely             0.0      0.0
# 01putrisalma       0.0      0.0
# 01sary             0.0      0.0
# 123hayoapa         0.0      0.0
# 15ayusafitri       0.0      0.0
#
# [5 rows x 3297 columns]

# %% [markdown]
# ### Normalizing rating values

# %%
matrix_pivot_ = matrix_pivot.values
user_ratings_mean = np.mean(matrix_pivot_, axis = 1)
user_rating = matrix_pivot_ - user_ratings_mean.reshape(-1,1)

# %% [markdown]
# ### Singular Value Decomposition

# %%
from scipy.sparse.linalg import svds
U, sigma, Vt = svds(user_rating, k = 50)

# %%
sigma = np.diag(sigma)

# %% [markdown]
# ### Predictive rating

# %%
all_user_predicted_ratings = np.dot(np.dot(U, sigma), Vt) + user_ratings_mean.reshape(-1, 1)

# %%
preds_df = pd.DataFrame(all_user_predicted_ratings, columns = matrix_pivot.columns, index=matrix_pivot.index)
preds_df
# Out:
# product       0,2 mm Therapy Air Mask Sheet  \
# reviewer
# 01lely                            -0.033156
# 01putrisalma                       0.010625
# 01sary                             0.001551
# 123hayoapa                         0.015527
# 15ayusafitri                       0.003480
# ...                                     ...
# zvnazole                          -0.005587
# zyshalu                           -0.013294
# zzarahs                           -0.003167
# zzfatimah                          0.002338
# zzulia                            -0.010500
#
# product       10% Lactic Acid (Infused with Rose)  \
# reviewer
# 01lely                                  -0.004630
# 01putrisalma                             0.000792
# 01sary                                  -0.001476
# 123hayoapa                               0.003253
# 15ayusafitri                             0.002537
# ...                                           ...
# zvnazole                                 0.001457
# zyshalu                                 -0.001248
# zzarahs                                  0.001298
# zzfatimah                                0.005823
# zzulia                                  -0.001756
#
# product       100% Cold-Pressed Virgin Marula Oil  \
# reviewer
# 01lely                                  -0.003819
# 01putrisalma                             0.002254
# 01sary                                  -0.000705
# 123hayoapa                              -0.000977
# 15ayusafitri                             0.003241
# ...                                           ...
# zvnazole                                 0.004361
# zyshalu                                 -0.001276
# zzarahs                                  0.004880
# zzfatimah                                0.013274
# zzulia                                   0.006799
#
# product       100% Organic Cold-Pressed Borage Seed Oil  \
# reviewer
# 01lely                                        -0.009635
# 01putrisalma                                   0.000406
# 01sary                                         0.000370
# 123hayoapa                                     0.002198
# 15ayusafitri                                   0.002244
# ...                                                 ...
# zvnazole                                       0.001318
# zyshalu                                       -0.002949
# zzarahs                                        0.002201
# zzfatimah                                      0.007428
# zzulia                                        -0.003696
#
# product       100% Organic Cold-Pressed Rose Hip Seed Oil  \
# reviewer
# 01lely                                           0.049237
# 01putrisalma                                     0.019684
# 01sary                                           0.005365
# 123hayoapa                                       0.016848
# 15ayusafitri                                     0.001346
# ...                                                   ...
# zvnazole                                         0.015749
# zyshalu                                          0.003175
# zzarahs                                          0.007945
# zzfatimah                                        0.037032
# zzulia                                          -0.006496
#
# product       100% Plant-Derived Squalane  100% Pure Camellia Dry Oil  \
# reviewer
# 01lely                           0.014808                   -0.006243
# 01putrisalma                     0.011667                   -0.000244
# 01sary                          -0.010139                   -0.000186
# 123hayoapa                       0.000153                    0.001836
# 15ayusafitri                    -0.003409                    0.002856
# ...                                   ...                         ...
# zvnazole                         0.006207                    0.001661
# zyshalu                         -0.008640                   -0.002109
# zzarahs                          0.011677                    0.001442
# zzfatimah                        0.034630                    0.004491
# zzulia                          -0.001663                   -0.002163
#
# product       100% Snail mucus Soothing Gel  14% AHA Swipes  \
# reviewer
# 01lely                             0.008375       -0.006995
# 01putrisalma                      -0.000047       -0.000289
# 01sary                             0.000662       -0.001281
# 123hayoapa                         0.003370        0.003455
# 15ayusafitri                       0.002452        0.002358
# ...                                     ...             ...
# zvnazole                           0.001480        0.000950
# zyshalu                            0.004431       -0.002174
# zzarahs                            0.003583        0.000730
# zzfatimah                          0.010501        0.004569
# zzulia                            -0.001534       -0.002361
#
# product       2 Minutes Brightening Gel  ...  \
# reviewer                                 ...
# 01lely                        -0.016372  ...
# 01putrisalma                   0.007549  ...
# 01sary                        -0.000038  ...
# 123hayoapa                     0.015547  ...
# 15ayusafitri                  -0.000510  ...
# ...                                 ...  ...
# zvnazole                       0.001608  ...
# zyshalu                       -0.007665  ...
# zzarahs                        0.001116  ...
# zzfatimah                      0.012420  ...
# zzulia                        -0.003471  ...
#
# product       wardah seaweed intensive night cream  wardah suncare  \
# reviewer
# 01lely                                    0.051089        0.095433
# 01putrisalma                             -0.005508       -0.006456
# 01sary                                   -0.001220        0.000716
# 123hayoapa                                0.001470       -0.005247
# 15ayusafitri                              0.005033        0.011756
# ...                                            ...             ...
# zvnazole                                 -0.000520        0.006899
# zyshalu                                   0.011587        0.027956
# zzarahs                                   0.001149        0.000714
# zzfatimah                                 0.005850        0.001047
# zzulia                                   -0.007494        0.006606
#
# product       watermelon glow  \
# reviewer
# 01lely              -0.023493
# 01putrisalma         0.005506
# 01sary              -0.003138
# 123hayoapa           0.002946
# 15ayusafitri         0.001465
# ...                       ...
# zvnazole             0.002039
# zyshalu             -0.003444
# zzarahs              0.003517
# zzfatimah            0.008600
# zzulia              -0.004184
#
# product       white beauty aqua facial wash with plant extract  \
# reviewer
# 01lely                                               -0.006377
# 01putrisalma                                          0.000164
# 01sary                                               -0.000447
# 123hayoapa                                           -0.006080
# 15ayusafitri                                          0.007603
# ...                                                        ...
# zvnazole                                              0.004319
# zyshalu                                               0.000228
# zzarahs                                               0.002938
# zzfatimah                                             0.005341
# zzulia                                               -0.010496
#
# product       whitening plus complex  whitening soap  wonder pore  zaitun oil  \
# reviewer
# 01lely                     -0.011017       -0.006941    -0.016992   -0.016342
# 01putrisalma               -0.000872       -0.002055    -0.000035    0.005095
# 01sary                      0.000854       -0.005362     0.007784   -0.002074
# 123hayoapa                 -0.002993       -0.000281    -0.008534    0.002337
# 15ayusafitri                0.004751        0.015957     0.006410    0.011011
# ...                              ...             ...          ...         ...
# zvnazole                    0.001492        0.009487    -0.003006    0.007397
# zyshalu                    -0.004142       -0.005065     0.012997    0.002577
# zzarahs                     0.002578       -0.000124     0.005001    0.000291
# zzfatimah                   0.004740        0.005966    -0.000579    0.006010
# zzulia                     -0.004374        0.007294     0.020087   -0.005167
#
# product       “Buffet”       “B” oil
# reviewer
# 01lely        0.024577 -4.931434e-03
# 01putrisalma  0.025665  7.925640e-04
# 01sary        0.006341 -1.701105e-03
# 123hayoapa    0.013906  5.204980e-07
# 15ayusafitri -0.009111  1.148843e-03
# ...                ...           ...
# zvnazole      0.005029  3.074178e-03
# zyshalu       0.011154  2.718208e-04
# zzarahs       0.017409  4.559316e-03
# zzfatimah     0.059716  1.161053e-02
# zzulia       -0.010467 -1.232599e-03
#
# [22359 rows x 3297 columns]

# %% [markdown]
# ### Creating recommendation

# %%
 def recommend_product(predictions_df, user, data_,num_recommendations):
   
    user_row_number = user
    sorted_user_predictions = preds_df.loc[user_row_number].sort_values(ascending=False)

    user_data = data_[data_.reviewer == (user)]
    user_full = user_data


    print('User {0} has already rated {1} product'.format(user, user_full.shape[0]))

    a = data.drop_duplicates(subset='product', keep='last')
    recommendations = (a[~a['product'].isin(user_full['product'])].
         merge(pd.DataFrame(sorted_user_predictions).reset_index(), how = 'left',
               left_on = 'product',
               right_on = 'product').
         rename(columns = {user_row_number: 'Predictions'}).
         sort_values('Predictions', ascending = False).
                       iloc[:num_recommendations, :-1]
                      )

    return user_full, recommendations

# %%
user = str(input("Enter the user id to whom you want to recommend : "))
already_rated, predictions = recommend_product(preds_df, user, data,5)
# Out:
# Enter the user id to whom you want to recommend : zzulia
# User zzulia has already rated 3 product

# %%
already_rated
# Out:
#        reviewer  rating                                   product
# 70013    zzulia       3                               Facial Mask
# 88179    zzulia       2                               Facial Mask
# 115840   zzulia       5  Pembersih Two In One Bengkoang Whitening

# %%
prod_pred = predictions['product']
prod_pred
# Out:
# 2040    Prominent Essence Facial Mask
# 2225         Facial Mask Bedak Dingin
# 1988                 Oil Control Mask
# 2000      White Aqua Serum Sheet Mask
# 1661                Essential Vitamin
# Name: product, dtype: object
